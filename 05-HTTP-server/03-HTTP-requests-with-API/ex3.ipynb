# %%
import requests

token = "eyJ0eXAiOiJKV1QiLCJub25jZSI6IjJMOXdiUnFMOVBwYzJ5aTk0VzhXa1dJNWI4UjFxa3l4THc3VGtzRmktWGciLCJhbGciOiJSUzI1NiIsIng1dCI6Im5PbzNaRHJPRFhFSzFqS1doWHNsSFJfS1hFZyIsImtpZCI6Im5PbzNaRHJPRFhFSzFqS1doWHNsSFJfS1hFZyJ9.....kkBZlgghio0gK5Ii0IGYYb-4V5OwtV2zO5s2ijNbqa-X_WQQgQU9BE5StXiwlpc5RrwECg_xTkOaQ0low2HktT3ara9UhwaSeunZeOGssAu5k-QggXmg87gmoRx0Pnwy9TnsE1kQ9gA1CMLhzUi18DM37tEq5R7W-GNSyX5MLoyAJ3Cj1d4JminaFac2tgzih3IVxRl63I57LPe966PyA33hZWp1X9vP8SlgmPu7uXh49s5BnPJV1ewCuHXdR35haX-dMLjcHXm3tFSGX0JSu5do5SQ6RKqdcSxJ6oIXGRXRVDW8XG-4i-c7jWmeuA_uBPcYFdaEAopMff4I9aPTNw"

# %%
def member_of():
    res = {}
    url = "https://graph.microsoft.com/beta/me/memberOf/"
    content = requests.get(url, headers={'Authorization': token})
    data = content.json()
    for i in data['value']:
        res[i['displayName']] = i['id']
    return res

teams = member_of()
for name, id in teams.items():
    print(name, id)
# Out:
# {'error': {'code': 'InvalidAuthenticationToken', 'message': 'Access token has expired or is not yet valid.', 'innerError': {'date': '2021-06-16T09:51:46', 'request-id': '88c89cce-88cd-4df1-8884-157a9214e3f1', 'client-request-id': '88c89cce-88cd-4df1-8884-157a9214e3f1'}}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-a5e07cf349e9> in <module>
#       9     return res
#      10
# ---> 11 teams = member_of()
#      12 for name, id in teams.items():
#      13     print(name, id)
#
# <ipython-input-50-a5e07cf349e9> in member_of()
#       5     data = content.json()
#       6     print(data)
# ----> 7     for i in data['value']:
#       8         res[i['displayName']] = i['id']
#       9     return res
#
# KeyError: 'value'

# %%
def get_channels(team_id):
    res = {}
    url = f"https://graph.microsoft.com/beta/teams/{team_id}/channels"
    content = requests.get(url, headers={'Authorization': token})
    data = content.json()
    for i in data['value']:
        res[i['displayName']] = i['id']
    return res

channels = get_channels("c1995755-c035-4c13-bc82-6b65b5c1d206")
for name, id in channels.items():
    print(name, id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-fe8ba300bb89> in <module>
#       8     return res
#       9
# ---> 10 channels = get_channels("c1995755-c035-4c13-bc82-6b65b5c1d206")
#      11 for name, id in channels.items():
#      12     print(name, id)
#
# <ipython-input-47-fe8ba300bb89> in get_channels(team_id)
#       4     content = requests.get(url, headers={'Authorization': token})
#       5     data = content.json()
# ----> 6     for i in data['value']:
#       7         res[i['displayName']] = i['id']
#       8     return res
#
# KeyError: 'value'

# %%
def get_messages(team_id, channel_id):
    res = {}
    msg = []
    index = 0
    start_url = "https://graph.microsoft.com/beta"
    url = f"{start_url}/teams/{team_id}/channels/{channel_id}/messages"
    content = requests.get(url, headers={'Authorization': token})
    data = content.json()
    for i in data['value']:
        reps = []
        msg.append({'msg':{'content':i['body']['content'], 'id':i['id']}, 'reps':[]})
        new_url = f"{start_url}/teams/{team_id}/channels/{channel_id}/messages/{i['id']}/replies"
        new_content = requests.get(new_url, headers={'Authorization': token})
        new_data = new_content.json()
        for j in new_data['value']:
            reps.append({'content':j['body']['content'], 'id': j['id']})
        msg[index]['reps'] = reps
        index += 1
    return msg

msgs = get_messages("c1995755-c035-4c13-bc82-6b65b5c1d206", "19:49df84fd0c2a4cf386866cb7cf90153a@thread.tacv2")
for i in msgs:
    print(i['msg'])
    print("\n")
    for j in i['reps']:
        print(j)
    print("\n\n\n")
# Out:
# {'content': 'A planifié une réunion<attachment id="1623829663703"></attachment>', 'id': '1623829662533'}
#
#
# {'content': '<systemEventMessage/>', 'id': '1623832836489'}
# {'content': 'quittez le call svp sinon il ne se termine pas\xa0', 'id': '1623832785981'}
# {'content': 'c&rré', 'id': '1623832574556'}
# {'content': '<p>mdr</p>', 'id': '1623832568741'}
# {'content': 'non plus', 'id': '1623832231650'}
# {'content': '<p>non plus</p>', 'id': '1623832225197'}
# {'content': 'non', 'id': '1623832216811'}
# {'content': "C'est fou pandas bien\xa0utilisé", 'id': '1623831943516'}
# {'content': "pd.set_option('display.max_rows', data.shape[0]+1)", 'id': '1623831064328'}
# {'content': '', 'id': '1623831030443'}
# {'content': 'Curieux', 'id': '1623830547557'}
# {'content': 'surtout curieux', 'id': '1623830545962'}
# {'content': 'Les deux ^^', 'id': '1623830530281'}
# {'content': '<systemEventMessage/>', 'id': '1623830448224'}
# {'content': '<div><div><at id="0">2 - Dataframe and plotting diagrams</at>&nbsp;comme hier, on fait une fait une session de "correction" des exos d\'hier</div>\n</div>', 'id': '1623829716034'}
# {'content': '<systemEventMessage/>', 'id': '1623742874682'}
# {'content': 'Merci', 'id': '1623742848675'}
# {'content': 'A toute merci', 'id': '1623742843487'}
# {'content': 'Merci !', 'id': '1623742842250'}
# {'content': '<p><span title="Heart" type="(heart)" class="animated-emoticon-50-heart"><img itemscope="" itemtype="http://schema.skype.com/Emoji" itemid="heart" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/heart/default/50_f.png" title="Heart" alt="❤️" style="width:50px; height:50px"></span></p>', 'id': '1623742840678'}
# {'content': 'merci', 'id': '1623742838961'}
# {'content': 'Merci !', 'id': '1623742835570'}
# {'content': "<p>Merci beaucoup! A tout à l'heure!</p>", 'id': '1623742832622'}
# {'content': '<div><div>Merci c\'etait très cool <span class="animated-emoticon-20" title="Visage au large sourire avec de grands yeux" type="1f603_grinningfacewithbigeyes"><img itemid="1f603_grinningfacewithbigeyes" itemscope="" itemtype="http://schema.skype.com/Emoji" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/1f603_grinningfacewithbigeyes/default/20_f.png?etag=v3" alt="😃" style="width:20px; height:20px"></span></div>\n</div>', 'id': '1623742832561'}
# {'content': 'super merci à toute', 'id': '1623742831580'}
# {'content': 'Merci (:', 'id': '1623742830925'}
# {'content': '<p>Quelle maison pour carapuce ?</p>', 'id': '1623742800679'}
# {'content': '<p>alright</p>', 'id': '1623742637130'}
# {'content': "je conseille d'utiliser des venv si on commence à importer des modules", 'id': '1623742614098'}
# {'content': '<p>requeter en SQL les dataframes est accepté ? </p>', 'id': '1623742609363'}
# {'content': 'tu peux faire shift+entrée aussi je crois', 'id': '1623742595967'}
# {'content': 'executer une cellule', 'id': '1623742569634'}
# {'content': 'quand on arrive sur notebook comment on lance le fichier ?', 'id': '1623742546466'}
# {'content': "pour moi c'est bon\xa0", 'id': '1623742543810'}
# {'content': '<div><div>c\'est tout bon pour moi <span class="animated-emoticon-20" title="Smile" type="smile"><img itemid="smile" itemscope="" itemtype="http://schema.skype.com/Emoji" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/smile/default/20_f.png?etag=v73" alt="🙂" style="width:20px; height:20px"></span></div>\n</div>', 'id': '1623742528292'}
#
#
#
#
# {'content': '<div><at id="0">2 - Dataframe and plotting diagrams</at><br>\n<br>\nVous êtes bien calme niveau questions 🙋\u200d♂️🤔🤔🤔 hésitez pas</div>', 'id': '1623774233769'}
#
#
# {'content': '<systemEventMessage/>', 'id': '1623832836489'}
# {'content': 'quittez le call svp sinon il ne se termine pas\xa0', 'id': '1623832785981'}
# {'content': 'c&rré', 'id': '1623832574556'}
# {'content': '<p>mdr</p>', 'id': '1623832568741'}
# {'content': 'non plus', 'id': '1623832231650'}
# {'content': '<p>non plus</p>', 'id': '1623832225197'}
# {'content': 'non', 'id': '1623832216811'}
# {'content': "C'est fou pandas bien\xa0utilisé", 'id': '1623831943516'}
# {'content': "pd.set_option('display.max_rows', data.shape[0]+1)", 'id': '1623831064328'}
# {'content': '', 'id': '1623831030443'}
# {'content': 'Curieux', 'id': '1623830547557'}
# {'content': 'surtout curieux', 'id': '1623830545962'}
# {'content': 'Les deux ^^', 'id': '1623830530281'}
# {'content': '<systemEventMessage/>', 'id': '1623830448224'}
# {'content': '<div><div><at id="0">2 - Dataframe and plotting diagrams</at>&nbsp;comme hier, on fait une fait une session de "correction" des exos d\'hier</div>\n</div>', 'id': '1623829716034'}
# {'content': '<systemEventMessage/>', 'id': '1623742874682'}
# {'content': 'Merci', 'id': '1623742848675'}
# {'content': 'A toute merci', 'id': '1623742843487'}
# {'content': 'Merci !', 'id': '1623742842250'}
# {'content': '<p><span title="Heart" type="(heart)" class="animated-emoticon-50-heart"><img itemscope="" itemtype="http://schema.skype.com/Emoji" itemid="heart" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/heart/default/50_f.png" title="Heart" alt="❤️" style="width:50px; height:50px"></span></p>', 'id': '1623742840678'}
# {'content': 'merci', 'id': '1623742838961'}
# {'content': 'Merci !', 'id': '1623742835570'}
# {'content': "<p>Merci beaucoup! A tout à l'heure!</p>", 'id': '1623742832622'}
# {'content': '<div><div>Merci c\'etait très cool <span class="animated-emoticon-20" title="Visage au large sourire avec de grands yeux" type="1f603_grinningfacewithbigeyes"><img itemid="1f603_grinningfacewithbigeyes" itemscope="" itemtype="http://schema.skype.com/Emoji" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/1f603_grinningfacewithbigeyes/default/20_f.png?etag=v3" alt="😃" style="width:20px; height:20px"></span></div>\n</div>', 'id': '1623742832561'}
# {'content': 'super merci à toute', 'id': '1623742831580'}
# {'content': 'Merci (:', 'id': '1623742830925'}
# {'content': '<p>Quelle maison pour carapuce ?</p>', 'id': '1623742800679'}
# {'content': '<p>alright</p>', 'id': '1623742637130'}
# {'content': "je conseille d'utiliser des venv si on commence à importer des modules", 'id': '1623742614098'}
# {'content': '<p>requeter en SQL les dataframes est accepté ? </p>', 'id': '1623742609363'}
# {'content': 'tu peux faire shift+entrée aussi je crois', 'id': '1623742595967'}
# {'content': 'executer une cellule', 'id': '1623742569634'}
# {'content': 'quand on arrive sur notebook comment on lance le fichier ?', 'id': '1623742546466'}
# {'content': "pour moi c'est bon\xa0", 'id': '1623742543810'}
# {'content': '<div><div>c\'est tout bon pour moi <span class="animated-emoticon-20" title="Smile" type="smile"><img itemid="smile" itemscope="" itemtype="http://schema.skype.com/Emoji" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/smile/default/20_f.png?etag=v73" alt="🙂" style="width:20px; height:20px"></span></div>\n</div>', 'id': '1623742528292'}
#
#
#
#
# {'content': 'A planifié une réunion<attachment id="1623699065873"></attachment>', 'id': '1623699064075'}
#
#
# {'content': '<systemEventMessage/>', 'id': '1623832836489'}
# {'content': 'quittez le call svp sinon il ne se termine pas\xa0', 'id': '1623832785981'}
# {'content': 'c&rré', 'id': '1623832574556'}
# {'content': '<p>mdr</p>', 'id': '1623832568741'}
# {'content': 'non plus', 'id': '1623832231650'}
# {'content': '<p>non plus</p>', 'id': '1623832225197'}
# {'content': 'non', 'id': '1623832216811'}
# {'content': "C'est fou pandas bien\xa0utilisé", 'id': '1623831943516'}
# {'content': "pd.set_option('display.max_rows', data.shape[0]+1)", 'id': '1623831064328'}
# {'content': '', 'id': '1623831030443'}
# {'content': 'Curieux', 'id': '1623830547557'}
# {'content': 'surtout curieux', 'id': '1623830545962'}
# {'content': 'Les deux ^^', 'id': '1623830530281'}
# {'content': '<systemEventMessage/>', 'id': '1623830448224'}
# {'content': '<div><div><at id="0">2 - Dataframe and plotting diagrams</at>&nbsp;comme hier, on fait une fait une session de "correction" des exos d\'hier</div>\n</div>', 'id': '1623829716034'}
# {'content': '<systemEventMessage/>', 'id': '1623742874682'}
# {'content': 'Merci', 'id': '1623742848675'}
# {'content': 'A toute merci', 'id': '1623742843487'}
# {'content': 'Merci !', 'id': '1623742842250'}
# {'content': '<p><span title="Heart" type="(heart)" class="animated-emoticon-50-heart"><img itemscope="" itemtype="http://schema.skype.com/Emoji" itemid="heart" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/heart/default/50_f.png" title="Heart" alt="❤️" style="width:50px; height:50px"></span></p>', 'id': '1623742840678'}
# {'content': 'merci', 'id': '1623742838961'}
# {'content': 'Merci !', 'id': '1623742835570'}
# {'content': "<p>Merci beaucoup! A tout à l'heure!</p>", 'id': '1623742832622'}
# {'content': '<div><div>Merci c\'etait très cool <span class="animated-emoticon-20" title="Visage au large sourire avec de grands yeux" type="1f603_grinningfacewithbigeyes"><img itemid="1f603_grinningfacewithbigeyes" itemscope="" itemtype="http://schema.skype.com/Emoji" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/1f603_grinningfacewithbigeyes/default/20_f.png?etag=v3" alt="😃" style="width:20px; height:20px"></span></div>\n</div>', 'id': '1623742832561'}
# {'content': 'super merci à toute', 'id': '1623742831580'}
# {'content': 'Merci (:', 'id': '1623742830925'}
# {'content': '<p>Quelle maison pour carapuce ?</p>', 'id': '1623742800679'}
# {'content': '<p>alright</p>', 'id': '1623742637130'}
# {'content': "je conseille d'utiliser des venv si on commence à importer des modules", 'id': '1623742614098'}
# {'content': '<p>requeter en SQL les dataframes est accepté ? </p>', 'id': '1623742609363'}
# {'content': 'tu peux faire shift+entrée aussi je crois', 'id': '1623742595967'}
# {'content': 'executer une cellule', 'id': '1623742569634'}
# {'content': 'quand on arrive sur notebook comment on lance le fichier ?', 'id': '1623742546466'}
# {'content': "pour moi c'est bon\xa0", 'id': '1623742543810'}
# {'content': '<div><div>c\'est tout bon pour moi <span class="animated-emoticon-20" title="Smile" type="smile"><img itemid="smile" itemscope="" itemtype="http://schema.skype.com/Emoji" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/smile/default/20_f.png?etag=v73" alt="🙂" style="width:20px; height:20px"></span></div>\n</div>', 'id': '1623742528292'}
#
#
#
#
# {'content': '<systemEventMessage/>', 'id': '1623328251786'}
#
#
# {'content': '<systemEventMessage/>', 'id': '1623832836489'}
# {'content': 'quittez le call svp sinon il ne se termine pas\xa0', 'id': '1623832785981'}
# {'content': 'c&rré', 'id': '1623832574556'}
# {'content': '<p>mdr</p>', 'id': '1623832568741'}
# {'content': 'non plus', 'id': '1623832231650'}
# {'content': '<p>non plus</p>', 'id': '1623832225197'}
# {'content': 'non', 'id': '1623832216811'}
# {'content': "C'est fou pandas bien\xa0utilisé", 'id': '1623831943516'}
# {'content': "pd.set_option('display.max_rows', data.shape[0]+1)", 'id': '1623831064328'}
# {'content': '', 'id': '1623831030443'}
# {'content': 'Curieux', 'id': '1623830547557'}
# {'content': 'surtout curieux', 'id': '1623830545962'}
# {'content': 'Les deux ^^', 'id': '1623830530281'}
# {'content': '<systemEventMessage/>', 'id': '1623830448224'}
# {'content': '<div><div><at id="0">2 - Dataframe and plotting diagrams</at>&nbsp;comme hier, on fait une fait une session de "correction" des exos d\'hier</div>\n</div>', 'id': '1623829716034'}
# {'content': '<systemEventMessage/>', 'id': '1623742874682'}
# {'content': 'Merci', 'id': '1623742848675'}
# {'content': 'A toute merci', 'id': '1623742843487'}
# {'content': 'Merci !', 'id': '1623742842250'}
# {'content': '<p><span title="Heart" type="(heart)" class="animated-emoticon-50-heart"><img itemscope="" itemtype="http://schema.skype.com/Emoji" itemid="heart" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/heart/default/50_f.png" title="Heart" alt="❤️" style="width:50px; height:50px"></span></p>', 'id': '1623742840678'}
# {'content': 'merci', 'id': '1623742838961'}
# {'content': 'Merci !', 'id': '1623742835570'}
# {'content': "<p>Merci beaucoup! A tout à l'heure!</p>", 'id': '1623742832622'}
# {'content': '<div><div>Merci c\'etait très cool <span class="animated-emoticon-20" title="Visage au large sourire avec de grands yeux" type="1f603_grinningfacewithbigeyes"><img itemid="1f603_grinningfacewithbigeyes" itemscope="" itemtype="http://schema.skype.com/Emoji" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/1f603_grinningfacewithbigeyes/default/20_f.png?etag=v3" alt="😃" style="width:20px; height:20px"></span></div>\n</div>', 'id': '1623742832561'}
# {'content': 'super merci à toute', 'id': '1623742831580'}
# {'content': 'Merci (:', 'id': '1623742830925'}
# {'content': '<p>Quelle maison pour carapuce ?</p>', 'id': '1623742800679'}
# {'content': '<p>alright</p>', 'id': '1623742637130'}
# {'content': "je conseille d'utiliser des venv si on commence à importer des modules", 'id': '1623742614098'}
# {'content': '<p>requeter en SQL les dataframes est accepté ? </p>', 'id': '1623742609363'}
# {'content': 'tu peux faire shift+entrée aussi je crois', 'id': '1623742595967'}
# {'content': 'executer une cellule', 'id': '1623742569634'}
# {'content': 'quand on arrive sur notebook comment on lance le fichier ?', 'id': '1623742546466'}
# {'content': "pour moi c'est bon\xa0", 'id': '1623742543810'}
# {'content': '<div><div>c\'est tout bon pour moi <span class="animated-emoticon-20" title="Smile" type="smile"><img itemid="smile" itemscope="" itemtype="http://schema.skype.com/Emoji" src="https://statics.teams.cdn.office.net/evergreen-assets/personal-expressions/v1/assets/emoticons/smile/default/20_f.png?etag=v73" alt="🙂" style="width:20px; height:20px"></span></div>\n</div>', 'id': '1623742528292'}
